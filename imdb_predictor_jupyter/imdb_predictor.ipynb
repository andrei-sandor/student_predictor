# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
df_imdb = pd.read_csv('movies.csv')

# %%
df_imdb
# Out:
#      Unnamed: 0                                        Poster_Link  \
# 0             4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 1             5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 2            10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 3            20  https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 4            23  https://m.media-amazon.com/images/M/MV5BMjlmZm...
# ..          ...                                                ...
# 330         988  https://m.media-amazon.com/images/M/MV5BMjM1Nj...
# 331         992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 332         994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 333         998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 334         999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                                           Series_Title Released_Year  \
# 0                                         12 Angry Men          1957
# 1        The Lord of the Rings: The Return of the King          2003
# 2    The Lord of the Rings: The Fellowship of the Ring          2001
# 3                                      Soorarai Pottru          2020
# 4                        Sen to Chihiro no kamikakushi          2001
# ..                                                 ...           ...
# 330                 Close Encounters of the Third Kind          1977
# 331                                    The Jungle Book          1967
# 332                                 A Hard Day's Night          1964
# 333                                           Lifeboat          1944
# 334                                       The 39 Steps          1935
#
#     Certificate  Runtime                         Genre  IMDB_Rating  \
# 0             U   96 min                  Crime, Drama          9.0
# 1             U  201 min      Action, Adventure, Drama          8.9
# 2             U  178 min      Action, Adventure, Drama          8.8
# 3             U  153 min                         Drama          8.6
# 4             U  125 min  Animation, Adventure, Family          8.6
# ..          ...      ...                           ...          ...
# 330           U  138 min                 Drama, Sci-Fi          7.6
# 331           U   78 min  Animation, Adventure, Family          7.6
# 332           U   87 min        Comedy, Music, Musical          7.6
# 333         NaN   97 min                    Drama, War          7.6
# 334         NaN   86 min      Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 0    A jury holdout attempts to prevent a miscarria...        96.0
# 1    Gandalf and Aragorn lead the World of Men agai...        94.0
# 2    A meek Hobbit from the Shire and eight compani...        92.0
# 3    Nedumaaran Rajangam "Maara" sets out to make t...         NaN
# 4    During her family's move to the suburbs, a sul...        96.0
# ..                                                 ...         ...
# 330  Roy Neary, an electric lineman, watches how hi...        90.0
# 331  Bagheera the Panther and Baloo the Bear have a...        65.0
# 332  Over two "typical" days in the life of The Bea...        96.0
# 333  Several survivors of a torpedoed merchant ship...        78.0
# 334  A man in London tries to help a counter-espion...        93.0
#
#                 Director              Star1              Star2  \
# 0           Sidney Lumet        Henry Fonda        Lee J. Cobb
# 1          Peter Jackson        Elijah Wood    Viggo Mortensen
# 2          Peter Jackson        Elijah Wood       Ian McKellen
# 3          Sudha Kongara             Suriya           Madhavan
# 4         Hayao Miyazaki      Daveigh Chase  Suzanne Pleshette
# ..                   ...                ...                ...
# 330     Steven Spielberg   Richard Dreyfuss  François Truffaut
# 331  Wolfgang Reitherman        Phil Harris    Sebastian Cabot
# 332       Richard Lester        John Lennon     Paul McCartney
# 333     Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 334     Alfred Hitchcock       Robert Donat  Madeleine Carroll
#
#                Star3              Star4  No_of_Votes        Gross
# 0      Martin Balsam       John Fiedler       689845    4,360,000
# 1       Ian McKellen      Orlando Bloom      1642758  377,845,905
# 2      Orlando Bloom          Sean Bean      1661481  315,544,750
# 3       Paresh Rawal  Aparna Balamurali        54995          NaN
# 4         Miyu Irino       Rumi Hiiragi       651376   10,055,859
# ..               ...                ...          ...          ...
# 330        Teri Garr     Melinda Dillon       184966  132,088,635
# 331      Louis Prima   Bruce Reitherman       166409  141,843,612
# 332  George Harrison        Ringo Starr        40351   13,780,024
# 333    Walter Slezak     William Bendix        26471          NaN
# 334   Lucie Mannheim     Godfrey Tearle        51853          NaN
#
# [335 rows x 17 columns]

# %%
df_imdb = df_imdb.drop(df_imdb[df_imdb['Released_Year'] == 'PG'].index)
df_imdb['Released_Year'] = df_imdb['Released_Year'].astype(float)

# %%
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '191 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '96 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '201 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '178 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '153 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '125 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '116 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '133 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '207 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '130 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '88 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '137 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '155 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'] == '89 min'].index)
# df_imdb = df_imdb.drop(df_imdb[df_imdb['Runtime'].str.len() > 3].index)
# df_imdb['Runtime'] = df_imdb['Runtime'].astype(int)

# %%
df_imdb['Gross'] = df_imdb['Gross'].str.replace(',', "")

# %%
df_imdb_clean = df_imdb.dropna()

# %%
df_imdb_clean
# Out:
#      Unnamed: 0                                        Poster_Link  \
# 0             4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 1             5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 2            10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 4            23  https://m.media-amazon.com/images/M/MV5BMjlmZm...
# 5            26  https://m.media-amazon.com/images/M/MV5BYmJmM2...
# ..          ...                                                ...
# 327         978  https://m.media-amazon.com/images/M/MV5BM2I1ZW...
# 328         984  https://m.media-amazon.com/images/M/MV5BMGQ0OG...
# 330         988  https://m.media-amazon.com/images/M/MV5BMjM1Nj...
# 331         992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 332         994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
#
#                                           Series_Title  Released_Year  \
# 0                                         12 Angry Men         1957.0
# 1        The Lord of the Rings: The Return of the King         2003.0
# 2    The Lord of the Rings: The Fellowship of the Ring         2001.0
# 4                        Sen to Chihiro no kamikakushi         2001.0
# 5                                      La vita è bella         1997.0
# ..                                                 ...            ...
# 327                       Planes, Trains & Automobiles         1987.0
# 328                                   The Muppet Movie         1979.0
# 330                 Close Encounters of the Third Kind         1977.0
# 331                                    The Jungle Book         1967.0
# 332                                 A Hard Day's Night         1964.0
#
#     Certificate  Runtime                         Genre  IMDB_Rating  \
# 0             U   96 min                  Crime, Drama          9.0
# 1             U  201 min      Action, Adventure, Drama          8.9
# 2             U  178 min      Action, Adventure, Drama          8.8
# 4             U  125 min  Animation, Adventure, Family          8.6
# 5             U  116 min        Comedy, Drama, Romance          8.6
# ..          ...      ...                           ...          ...
# 327           U   93 min                 Comedy, Drama          7.6
# 328           U   95 min     Adventure, Comedy, Family          7.6
# 330           U  138 min                 Drama, Sci-Fi          7.6
# 331           U   78 min  Animation, Adventure, Family          7.6
# 332           U   87 min        Comedy, Music, Musical          7.6
#
#                                               Overview  Meta_score  \
# 0    A jury holdout attempts to prevent a miscarria...        96.0
# 1    Gandalf and Aragorn lead the World of Men agai...        94.0
# 2    A meek Hobbit from the Shire and eight compani...        92.0
# 4    During her family's move to the suburbs, a sul...        96.0
# 5    When an open-minded Jewish librarian and his s...        59.0
# ..                                                 ...         ...
# 327  A man must struggle to travel home for Thanksg...        72.0
# 328  Kermit and his newfound friends trek across Am...        74.0
# 330  Roy Neary, an electric lineman, watches how hi...        90.0
# 331  Bagheera the Panther and Baloo the Bear have a...        65.0
# 332  Over two "typical" days in the life of The Bea...        96.0
#
#                 Director             Star1              Star2  \
# 0           Sidney Lumet       Henry Fonda        Lee J. Cobb
# 1          Peter Jackson       Elijah Wood    Viggo Mortensen
# 2          Peter Jackson       Elijah Wood       Ian McKellen
# 4         Hayao Miyazaki     Daveigh Chase  Suzanne Pleshette
# 5        Roberto Benigni   Roberto Benigni  Nicoletta Braschi
# ..                   ...               ...                ...
# 327          John Hughes      Steve Martin         John Candy
# 328        James Frawley        Jim Henson           Frank Oz
# 330     Steven Spielberg  Richard Dreyfuss  François Truffaut
# 331  Wolfgang Reitherman       Phil Harris    Sebastian Cabot
# 332       Richard Lester       John Lennon     Paul McCartney
#
#                  Star3             Star4  No_of_Votes      Gross
# 0        Martin Balsam      John Fiedler       689845    4360000
# 1         Ian McKellen     Orlando Bloom      1642758  377845905
# 2        Orlando Bloom         Sean Bean      1661481  315544750
# 4           Miyu Irino      Rumi Hiiragi       651376   10055859
# 5    Giorgio Cantarini   Giustino Durano       623629   57598247
# ..                 ...               ...          ...        ...
# 327       Laila Robins    Michael McKean       124773   49530280
# 328       Jerry Nelson      Richard Hunt        32802   76657000
# 330          Teri Garr    Melinda Dillon       184966  132088635
# 331        Louis Prima  Bruce Reitherman       166409  141843612
# 332    George Harrison       Ringo Starr        40351   13780024
#
# [182 rows x 17 columns]

# %%
#Linear regression
X = pd.DataFrame()

X["Released_Year"] = df_imdb_clean['Released_Year']
# X["Runtime"] = df_imdb['Runtime']
X['Meta Score'] = df_imdb_clean['Meta_score']
X['Votes'] = df_imdb_clean['No_of_Votes']
X['Gross'] =  df_imdb_clean['Gross']


y = pd.DataFrame()
y['imdb'] = df_imdb_clean['IMDB_Rating']

X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model = LinearRegression()

model.fit(X_train, y_train)

y_predict = model.predict(x_test)
print(r2_score(y_test, y_predict))
print(mean_absolute_error(y_test, y_predict))
print(mean_squared_error(y_test, y_predict))
# Out:
# 0.398602279024477
# 0.1869570851962384
# 0.050914533134450775

# %%
#MLP Regresor
X = pd.DataFrame()

X["Released_Year"] = df_imdb_clean['Released_Year']
# X["Runtime"] = df_imdb['Runtime']
X['Meta Score'] = df_imdb_clean['Meta_score']
X['Votes'] = df_imdb_clean['No_of_Votes']
X['Gross'] =  df_imdb_clean['Gross']


y = pd.DataFrame()
y['imdb'] = df_imdb_clean['IMDB_Rating']

X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model = MLPRegressor(random_state=0)

model.fit(X_train, y_train)

y_predict = model.predict(x_test)
print(r2_score(y_test, y_predict))
print(mean_absolute_error(y_test, y_predict))
print(mean_squared_error(y_test, y_predict))
# Out:
# -3266945094669.81
# 343897.1760744341
# 276580669446.5645
# /Users/andreisandor/anaconda3/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Decision Tree Regressor
X = pd.DataFrame()

X["Released_Year"] = df_imdb_clean['Released_Year']
# X["Runtime"] = df_imdb['Runtime']
X['Meta Score'] = df_imdb_clean['Meta_score']
X['Votes'] = df_imdb_clean['No_of_Votes']
X['Gross'] =  df_imdb_clean['Gross']


y = pd.DataFrame()
y['imdb'] = df_imdb_clean['IMDB_Rating']

X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model = DecisionTreeRegressor(random_state=0)

model.fit(X_train, y_train)

y_predict = model.predict(x_test)
print(r2_score(y_test, y_predict))
print(mean_absolute_error(y_test, y_predict))
print(mean_squared_error(y_test, y_predict))
# Out:
# 0.25297670405521844
# 0.18918918918918934
# 0.06324324324324336

# %%
# RandomForestRegressor
X = pd.DataFrame()

X["Released_Year"] = df_imdb_clean['Released_Year']
# X["Runtime"] = df_imdb['Runtime']
X['Meta Score'] = df_imdb_clean['Meta_score']
X['Votes'] = df_imdb_clean['No_of_Votes']
X['Gross'] =  df_imdb_clean['Gross']


y = pd.DataFrame()
y['imdb'] = df_imdb_clean['IMDB_Rating']

X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model = RandomForestRegressor(random_state=0)

model.fit(X_train, y_train)

y_predict = model.predict(x_test)
print(r2_score(y_test, y_predict))
print(mean_absolute_error(y_test, y_predict))
print(mean_squared_error(y_test, y_predict))
# Out:
# 0.5555208196721273
# 0.15137837837837892
# 0.03762975675675707
# /var/folders/zp/j6n5zjwx4g184f0x4g1j4llc0000gn/T/ipykernel_88101/2465176139.py:18: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
